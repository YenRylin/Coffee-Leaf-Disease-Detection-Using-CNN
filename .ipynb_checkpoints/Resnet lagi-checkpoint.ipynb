# %%
import os
import random
import shutil
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras import Model
from tensorflow.keras.utils import img_to_array, load_img
from shutil import copyfile
from PIL import Image
# %matplotlib inline

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.95 and logs.get('val_accuracy')>=0.90):
      print("\nReached 95% accuracy so cancelling training!")
      self.model.stop_training = True

callbacks = myCallback()

# %%
# Resized gambar agar memiliku jumlah pixel yang sama
def copy_to_working(path, new_path):
  for filename in os.scandir(path):
#     img = Image.open(os.path.join(path, filename.name))
#     img_resized= img.resize(new_size)
#     img_resized.save(os.path.join(new_path, filename.name))
    copyfile(os.path.join(path, filename.name), os.path.join(new_path, filename.name))

# %%
# Membuat direktori untuk menempatka data yang akan digunakan

resized_dir = './train'
source_dir = './data'

if os.path.exists(resized_dir):
  shutil.rmtree(resized_dir)

def create_train_valid_dirs(resized_path):
  os.mkdir(resized_path)
  os.mkdir(os.path.join(resized_path, 'train'))
  os.mkdir(os.path.join(resized_path, 'valid'))

  for foldername in os.listdir(os.path.join(source_dir, 'train')):
    for i in os.listdir(resized_path):
         os.mkdir(os.path.join(resized_path, i, foldername))

try:
  create_train_valid_dirs(resized_path=resized_dir)
except FileExistsError:
  print("File Sudah Ada")

# %%
# Train Source
train_miner_source = os.path.join(source_dir, 'train/miner/')
train_healthy_source = os.path.join(source_dir, 'train/nodisease/')
train_phoma_source = os.path.join(source_dir, 'train/phoma/')
train_rust_source = os.path.join(source_dir, 'train/rust/')

# valid Source
valid_miner_source = os.path.join(source_dir, 'valid/miner/')
valid_healthy_source = os.path.join(source_dir, 'valid/nodisease/')
valid_phoma_source = os.path.join(source_dir, 'valid/phoma/')
valid_rust_source = os.path.join(source_dir, 'valid/rust/')

# Train Resized
train_miner_resized = os.path.join(resized_dir, 'train/miner/')
train_healthy_resized = os.path.join(resized_dir, 'train/nodisease/')
train_phoma_resized = os.path.join(resized_dir, 'train/phoma/')
train_rust_resized = os.path.join(resized_dir, 'train/rust/')

# valid Resized
valid_miner_resized = os.path.join(resized_dir, 'valid/miner/')
valid_healthy_resized = os.path.join(resized_dir, 'valid/nodisease/')
valid_phoma_resized = os.path.join(resized_dir, 'valid/phoma/')
valid_rust_resized = os.path.join(resized_dir, 'valid/rust/')

# %%
# Melihat contoh ukuran dataset
sample_image  = load_img('./data/train/bercak-daun/20241027_124426_jpg.rf.6aa3233e0cdcfcc848cf051596313831.jpg')
sample_array = img_to_array(sample_image)
print(f"Each image has shape: {sample_array.shape}")

sample_image  = load_img('./data/valid/bercak-daun/WhatsApp-Image-2024-11-01-at-16-33-45_ad59510e_jpg.rf.53f1f39a075b8117bbb254299a3b069e.jpg')
sample_array = img_to_array(sample_image)
print(f"Each image has shape: {sample_array.shape}")
# Out:
# Each image has shape: (640, 640, 3)
# Each image has shape: (640, 640, 3)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Path dataset
train_dir = './data/train'
valid_dir = './data/valid'

# Data augmentation untuk data pelatihan
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Data generator untuk validasi
valid_datagen = ImageDataGenerator(rescale=1./255)

# Menggunakan generator untuk memuat data
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),  # Resolusi gambar untuk ResNet
    batch_size=32,
    class_mode='categorical'
)

valid_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 686 images belonging to 4 classes.
# Found 141 images belonging to 4 classes.

# %%
import os
import numpy as np
import tensorflow as tf
from PIL import Image
from tensorflow.keras.preprocessing.image import img_to_array

# Tentukan path folder train dan validation
train_dir = './data/train'
valid_dir = './data/valid'
test_dir = './data/test'

# Tentukan dimensi gambar yang diharapkan
input_shape = (224, 224)

# Load dataset train dan valid menjadi array numpy
train_images = []
train_labels = []
val_images = []
val_labels = []
classes = ['bercak-daun', 'hawar-daun', 'karat-daun', 'pengorok-daun']

# Fungsi untuk memuat dan mengubah ukuran gambar
def load_and_resize_image(image_path, target_size=(224, 224)):
    img = Image.open(image_path).convert('RGB')
    img = img.resize(target_size, Image.Resampling.LANCZOS)
    return img_to_array(img)

# Memuat dataset train
for class_index, class_name in enumerate(classes):
    class_dir = os.path.join(train_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
        img_array = load_and_resize_image(image_path, input_shape)
        train_images.append(img_array)
        train_labels.append(class_index)

# Memuat dataset validation
for class_index, class_name in enumerate(classes):
    class_dir = os.path.join(valid_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
        img_array = load_and_resize_image(image_path, input_shape)
        val_images.append(img_array)
        val_labels.append(class_index)

# Convert lists to numpy arrays
train_images = np.array(train_images)
train_labels = np.array(train_labels)
val_images = np.array(val_images)
val_labels = np.array(val_labels)

# Pastikan dimensi gambar sudah benar
print("Train Images shape:", train_images.shape)
print("Validation Images shape:", val_images.shape)
# Out:
# Train Images shape: (686, 224, 224, 3)
# Validation Images shape: (141, 224, 224, 3)

# %%
# Load dataset test
test_images = []
test_labels = []  # Tambahkan jika ada label untuk dataset test

for class_index, class_name in enumerate(classes):
    class_dir = os.path.join(test_dir, class_name)
    for image_name in os.listdir(class_dir):
        image_path = os.path.join(class_dir, image_name)
        img_array = load_and_resize_image(image_path, input_shape)
        test_images.append(img_array)
        test_labels.append(class_index)  # Opsional jika ada label

test_images = np.array(test_images)
print("Test Images shape:", test_images.shape)
# Out:
# Test Images shape: (92, 224, 224, 3)

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input

# Tentukan input_shape sesuai dengan ResNet50 (224, 224, 3)
input_shape = (224, 224, 3)

# Muat model ResNet50 dengan pre-trained weights dan exclude top layer (untuk fine-tuning)
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)

# Tambahkan layer tambahan setelah base model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(4, activation='softmax')  # 4 kelas output
])

# Freeze base model
base_model.trainable = False

# Compile model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Menampilkan summary model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         8,196 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,595,908 (90.01 MB)
#  Trainable params: 8,196 (32.02 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
history = model.fit(
    train_images, 
    train_labels, 
    epochs=25, 
    verbose=1, 
    validation_data=(val_images, val_labels)
)
# Out:
# Epoch 1/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.3488 - loss: 1.4312 - val_accuracy: 0.4681 - val_loss: 1.2560
# Epoch 2/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.5704 - loss: 0.9900 - val_accuracy: 0.5887 - val_loss: 1.0879
# Epoch 3/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.6567 - loss: 0.8188 - val_accuracy: 0.6596 - val_loss: 0.9494
# Epoch 4/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.7579 - loss: 0.6661 - val_accuracy: 0.6241 - val_loss: 0.9009
# Epoch 5/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.7843 - loss: 0.6428 - val_accuracy: 0.7163 - val_loss: 0.8307
# Epoch 6/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8382 - loss: 0.5376 - val_accuracy: 0.7305 - val_loss: 0.7946
# Epoch 7/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.8303 - loss: 0.4996 - val_accuracy: 0.7234 - val_loss: 0.7697
# Epoch 8/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 286s 14s/step - accuracy: 0.8583 - loss: 0.4667 - val_accuracy: 0.7163 - val_loss: 0.7479
# Epoch 9/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8763 - loss: 0.4157 - val_accuracy: 0.7163 - val_loss: 0.7433
# Epoch 10/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.8957 - loss: 0.4029 - val_accuracy: 0.7163 - val_loss: 0.7260
# Epoch 11/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9113 - loss: 0.3725 - val_accuracy: 0.7376 - val_loss: 0.7162
# Epoch 12/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 56s 3s/step - accuracy: 0.9363 - loss: 0.3285 - val_accuracy: 0.7589 - val_loss: 0.6994
# Epoch 13/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 55s 3s/step - accuracy: 0.9409 - loss: 0.3041 - val_accuracy: 0.7447 - val_loss: 0.6858
# Epoch 14/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 68s 3s/step - accuracy: 0.9483 - loss: 0.2863 - val_accuracy: 0.7518 - val_loss: 0.7065
# Epoch 15/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9387 - loss: 0.2800 - val_accuracy: 0.7518 - val_loss: 0.6866
# Epoch 16/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9493 - loss: 0.2739 - val_accuracy: 0.7447 - val_loss: 0.6635
# Epoch 17/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9732 - loss: 0.2489 - val_accuracy: 0.7518 - val_loss: 0.6463
# Epoch 18/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9691 - loss: 0.2226 - val_accuracy: 0.7730 - val_loss: 0.6322
# Epoch 19/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9724 - loss: 0.2102 - val_accuracy: 0.7801 - val_loss: 0.6295
# Epoch 20/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9714 - loss: 0.2099 - val_accuracy: 0.7943 - val_loss: 0.6274
# Epoch 21/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9751 - loss: 0.1970 - val_accuracy: 0.7872 - val_loss: 0.6157
# Epoch 22/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9812 - loss: 0.1771 - val_accuracy: 0.7943 - val_loss: 0.6116
# Epoch 23/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9820 - loss: 0.1913 - val_accuracy: 0.7872 - val_loss: 0.6196
# Epoch 24/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9920 - loss: 0.1631 - val_accuracy: 0.7801 - val_loss: 0.6068
# Epoch 25/25
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9906 - loss: 0.1607 - val_accuracy: 0.7943 - val_loss: 0.6069

# %%
# Plot the training and validation accuracies for each epoch

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

#Train and Validation Accuracy
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

#Train and Validation Loss
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()
plt.show()

# Confusion Matrix Heatmap
# class_labels = sorted(os.listdir('/kaggle/input/coffee-leaf-diseases/train'))
predictions = model.predict(val_images)
predicted_labels = np.argmax(predictions, axis=1)
# true_labels = val_generator.classes
cm = confusion_matrix(val_labels, predicted_labels)
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='.2f', xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step

# %%
prediksi = model.predict(val_images)
y_pred = np.argmax(prediksi, axis=1)
# y_true = val_generator.labels

print(classification_report(val_labels, y_pred))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82        64
#            1       0.75      0.86      0.80        21
#            2       0.74      0.80      0.77        35
#            3       0.83      0.71      0.77        21
#
#     accuracy                           0.79       141
#    macro avg       0.79      0.79      0.79       141
# weighted avg       0.80      0.79      0.79       141

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# Validation with intentionally wrong labels
wrong_labels = np.random.permutation(val_labels)

predicted_probs = model.predict(val_images)
predicted_labels = np.argmax(predicted_probs, axis=1)

print("Validation Results with Wrong Labels:")
for idx, (actual, wrong, pred) in enumerate(zip(val_labels, wrong_labels, predicted_labels)):
    confidence = np.max(predicted_probs[idx])
    status = "Correct" if pred == actual else "Wrong"
    print(f"Image {idx + 1}: Actual Label = {actual}, Wrong Label = {wrong}, Predicted Label = {pred}, "
          f"Confidence = {confidence:.2f}, Status = {status}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step
# Validation Results with Wrong Labels:
# Image 1: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.88, Status = Correct
# Image 2: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.97, Status = Correct
# Image 3: Actual Label = 0, Wrong Label = 3, Predicted Label = 0, Confidence = 0.86, Status = Correct
# Image 4: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.75, Status = Correct
# Image 5: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.89, Status = Correct
# Image 6: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.78, Status = Correct
# Image 7: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.82, Status = Correct
# Image 8: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.99, Status = Correct
# Image 9: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.97, Status = Correct
# Image 10: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.97, Status = Correct
# Image 11: Actual Label = 0, Wrong Label = 3, Predicted Label = 0, Confidence = 0.96, Status = Correct
# Image 12: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.79, Status = Correct
# Image 13: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.98, Status = Correct
# Image 14: Actual Label = 0, Wrong Label = 2, Predicted Label = 1, Confidence = 0.76, Status = Wrong
# Image 15: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.90, Status = Correct
# Image 16: Actual Label = 0, Wrong Label = 0, Predicted Label = 3, Confidence = 0.44, Status = Wrong
# Image 17: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.93, Status = Correct
# Image 18: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.55, Status = Correct
# Image 19: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.97, Status = Correct
# Image 20: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.62, Status = Correct
# Image 21: Actual Label = 0, Wrong Label = 0, Predicted Label = 1, Confidence = 0.58, Status = Wrong
# Image 22: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.74, Status = Correct
# Image 23: Actual Label = 0, Wrong Label = 2, Predicted Label = 1, Confidence = 0.96, Status = Wrong
# Image 24: Actual Label = 0, Wrong Label = 1, Predicted Label = 2, Confidence = 0.58, Status = Wrong
# Image 25: Actual Label = 0, Wrong Label = 0, Predicted Label = 1, Confidence = 0.62, Status = Wrong
# Image 26: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.89, Status = Correct
# Image 27: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.62, Status = Correct
# Image 28: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.80, Status = Correct
# Image 29: Actual Label = 0, Wrong Label = 2, Predicted Label = 2, Confidence = 0.50, Status = Wrong
# Image 30: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.83, Status = Correct
# Image 31: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.53, Status = Correct
# Image 32: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.80, Status = Correct
# Image 33: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.66, Status = Correct
# Image 34: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.74, Status = Correct
# Image 35: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.92, Status = Correct
# Image 36: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.89, Status = Correct
# Image 37: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.95, Status = Correct
# Image 38: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.96, Status = Correct
# Image 39: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.93, Status = Correct
# Image 40: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.53, Status = Correct
# Image 41: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.79, Status = Correct
# Image 42: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.51, Status = Correct
# Image 43: Actual Label = 0, Wrong Label = 2, Predicted Label = 1, Confidence = 0.67, Status = Wrong
# Image 44: Actual Label = 0, Wrong Label = 3, Predicted Label = 2, Confidence = 0.40, Status = Wrong
# Image 45: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.76, Status = Correct
# Image 46: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.49, Status = Correct
# Image 47: Actual Label = 0, Wrong Label = 0, Predicted Label = 2, Confidence = 0.47, Status = Wrong
# Image 48: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.94, Status = Correct
# Image 49: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.69, Status = Correct
# Image 50: Actual Label = 0, Wrong Label = 2, Predicted Label = 2, Confidence = 0.77, Status = Wrong
# Image 51: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.98, Status = Correct
# Image 52: Actual Label = 0, Wrong Label = 0, Predicted Label = 2, Confidence = 0.57, Status = Wrong
# Image 53: Actual Label = 0, Wrong Label = 3, Predicted Label = 0, Confidence = 0.84, Status = Correct
# Image 54: Actual Label = 0, Wrong Label = 3, Predicted Label = 0, Confidence = 0.54, Status = Correct
# Image 55: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.46, Status = Correct
# Image 56: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.62, Status = Correct
# Image 57: Actual Label = 0, Wrong Label = 3, Predicted Label = 2, Confidence = 0.70, Status = Wrong
# Image 58: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.56, Status = Correct
# Image 59: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.45, Status = Correct
# Image 60: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.76, Status = Correct
# Image 61: Actual Label = 0, Wrong Label = 1, Predicted Label = 0, Confidence = 0.78, Status = Correct
# Image 62: Actual Label = 0, Wrong Label = 3, Predicted Label = 0, Confidence = 0.62, Status = Correct
# Image 63: Actual Label = 0, Wrong Label = 0, Predicted Label = 0, Confidence = 0.94, Status = Correct
# Image 64: Actual Label = 0, Wrong Label = 2, Predicted Label = 0, Confidence = 0.85, Status = Correct
# Image 65: Actual Label = 1, Wrong Label = 3, Predicted Label = 1, Confidence = 0.78, Status = Correct
# Image 66: Actual Label = 1, Wrong Label = 2, Predicted Label = 1, Confidence = 0.40, Status = Correct
# Image 67: Actual Label = 1, Wrong Label = 3, Predicted Label = 1, Confidence = 0.51, Status = Correct
# Image 68: Actual Label = 1, Wrong Label = 0, Predicted Label = 3, Confidence = 0.86, Status = Wrong
# Image 69: Actual Label = 1, Wrong Label = 1, Predicted Label = 1, Confidence = 1.00, Status = Correct
# Image 70: Actual Label = 1, Wrong Label = 2, Predicted Label = 1, Confidence = 0.82, Status = Correct
# Image 71: Actual Label = 1, Wrong Label = 0, Predicted Label = 1, Confidence = 0.96, Status = Correct
# Image 72: Actual Label = 1, Wrong Label = 0, Predicted Label = 1, Confidence = 0.61, Status = Correct
# Image 73: Actual Label = 1, Wrong Label = 3, Predicted Label = 1, Confidence = 0.82, Status = Correct
# Image 74: Actual Label = 1, Wrong Label = 2, Predicted Label = 1, Confidence = 0.89, Status = Correct
# Image 75: Actual Label = 1, Wrong Label = 1, Predicted Label = 1, Confidence = 0.56, Status = Correct
# Image 76: Actual Label = 1, Wrong Label = 1, Predicted Label = 1, Confidence = 0.90, Status = Correct
# Image 77: Actual Label = 1, Wrong Label = 3, Predicted Label = 1, Confidence = 1.00, Status = Correct
# Image 78: Actual Label = 1, Wrong Label = 0, Predicted Label = 1, Confidence = 0.90, Status = Correct
# Image 79: Actual Label = 1, Wrong Label = 2, Predicted Label = 1, Confidence = 0.97, Status = Correct
# Image 80: Actual Label = 1, Wrong Label = 1, Predicted Label = 1, Confidence = 0.71, Status = Correct
# Image 81: Actual Label = 1, Wrong Label = 2, Predicted Label = 0, Confidence = 0.47, Status = Wrong
# Image 82: Actual Label = 1, Wrong Label = 0, Predicted Label = 1, Confidence = 0.65, Status = Correct
# Image 83: Actual Label = 1, Wrong Label = 0, Predicted Label = 3, Confidence = 0.90, Status = Wrong
# Image 84: Actual Label = 1, Wrong Label = 3, Predicted Label = 1, Confidence = 0.69, Status = Correct
# Image 85: Actual Label = 1, Wrong Label = 0, Predicted Label = 1, Confidence = 0.81, Status = Correct
# Image 86: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.94, Status = Correct
# Image 87: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.89, Status = Correct
# Image 88: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.90, Status = Correct
# Image 89: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.99, Status = Correct
# Image 90: Actual Label = 2, Wrong Label = 1, Predicted Label = 2, Confidence = 0.86, Status = Correct
# Image 91: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.54, Status = Correct
# Image 92: Actual Label = 2, Wrong Label = 0, Predicted Label = 0, Confidence = 0.82, Status = Wrong
# Image 93: Actual Label = 2, Wrong Label = 0, Predicted Label = 0, Confidence = 0.45, Status = Wrong
# Image 94: Actual Label = 2, Wrong Label = 3, Predicted Label = 2, Confidence = 0.95, Status = Correct
# Image 95: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.62, Status = Correct
# Image 96: Actual Label = 2, Wrong Label = 3, Predicted Label = 2, Confidence = 0.93, Status = Correct
# Image 97: Actual Label = 2, Wrong Label = 3, Predicted Label = 2, Confidence = 0.71, Status = Correct
# Image 98: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.87, Status = Correct
# Image 99: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.89, Status = Correct
# Image 100: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.95, Status = Correct
# Image 101: Actual Label = 2, Wrong Label = 2, Predicted Label = 0, Confidence = 0.70, Status = Wrong
# Image 102: Actual Label = 2, Wrong Label = 1, Predicted Label = 2, Confidence = 0.46, Status = Correct
# Image 103: Actual Label = 2, Wrong Label = 3, Predicted Label = 0, Confidence = 0.49, Status = Wrong
# Image 104: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.75, Status = Correct
# Image 105: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.85, Status = Correct
# Image 106: Actual Label = 2, Wrong Label = 3, Predicted Label = 0, Confidence = 0.55, Status = Wrong
# Image 107: Actual Label = 2, Wrong Label = 0, Predicted Label = 0, Confidence = 0.63, Status = Wrong
# Image 108: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.97, Status = Correct
# Image 109: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.85, Status = Correct
# Image 110: Actual Label = 2, Wrong Label = 3, Predicted Label = 2, Confidence = 0.83, Status = Correct
# Image 111: Actual Label = 2, Wrong Label = 1, Predicted Label = 2, Confidence = 0.49, Status = Correct
# Image 112: Actual Label = 2, Wrong Label = 1, Predicted Label = 2, Confidence = 0.77, Status = Correct
# Image 113: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.75, Status = Correct
# Image 114: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.47, Status = Correct
# Image 115: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.39, Status = Correct
# Image 116: Actual Label = 2, Wrong Label = 0, Predicted Label = 0, Confidence = 0.76, Status = Wrong
# Image 117: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.52, Status = Correct
# Image 118: Actual Label = 2, Wrong Label = 2, Predicted Label = 2, Confidence = 0.78, Status = Correct
# Image 119: Actual Label = 2, Wrong Label = 3, Predicted Label = 2, Confidence = 0.78, Status = Correct
# Image 120: Actual Label = 2, Wrong Label = 0, Predicted Label = 2, Confidence = 0.63, Status = Correct
# Image 121: Actual Label = 3, Wrong Label = 2, Predicted Label = 3, Confidence = 0.44, Status = Correct
# Image 122: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 0.73, Status = Correct
# Image 123: Actual Label = 3, Wrong Label = 2, Predicted Label = 3, Confidence = 0.50, Status = Correct
# Image 124: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 0.90, Status = Correct
# Image 125: Actual Label = 3, Wrong Label = 0, Predicted Label = 2, Confidence = 0.59, Status = Wrong
# Image 126: Actual Label = 3, Wrong Label = 3, Predicted Label = 2, Confidence = 0.48, Status = Wrong
# Image 127: Actual Label = 3, Wrong Label = 2, Predicted Label = 3, Confidence = 0.56, Status = Correct
# Image 128: Actual Label = 3, Wrong Label = 1, Predicted Label = 3, Confidence = 0.57, Status = Correct
# Image 129: Actual Label = 3, Wrong Label = 1, Predicted Label = 1, Confidence = 0.64, Status = Wrong
# Image 130: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 1.00, Status = Correct
# Image 131: Actual Label = 3, Wrong Label = 2, Predicted Label = 3, Confidence = 0.74, Status = Correct
# Image 132: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 0.94, Status = Correct
# Image 133: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 0.71, Status = Correct
# Image 134: Actual Label = 3, Wrong Label = 1, Predicted Label = 3, Confidence = 0.51, Status = Correct
# Image 135: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 0.82, Status = Correct
# Image 136: Actual Label = 3, Wrong Label = 3, Predicted Label = 3, Confidence = 0.50, Status = Correct
# Image 137: Actual Label = 3, Wrong Label = 0, Predicted Label = 0, Confidence = 0.59, Status = Wrong
# Image 138: Actual Label = 3, Wrong Label = 2, Predicted Label = 0, Confidence = 0.69, Status = Wrong
# Image 139: Actual Label = 3, Wrong Label = 0, Predicted Label = 2, Confidence = 0.44, Status = Wrong
# Image 140: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 0.51, Status = Correct
# Image 141: Actual Label = 3, Wrong Label = 0, Predicted Label = 3, Confidence = 0.42, Status = Correct

# %%
# Testing without labels
print("\nTest Results (No Labels):")
test_predictions = model.predict(test_images)  # Ganti `val_images` dengan test dataset jika tersedia
test_predicted_labels = np.argmax(test_predictions, axis=1)

for idx, pred in enumerate(test_predicted_labels):
    confidence = np.max(test_predictions[idx])
    print(f"Image {idx + 1}: Predicted Label = {pred}, Confidence = {confidence:.2f}")
# Out:
# Test Results (No Labels):
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step
# Image 1: Predicted Label = 0, Confidence = 0.92
# Image 2: Predicted Label = 0, Confidence = 0.76
# Image 3: Predicted Label = 0, Confidence = 0.61
# Image 4: Predicted Label = 0, Confidence = 0.74
# Image 5: Predicted Label = 0, Confidence = 0.85
# Image 6: Predicted Label = 0, Confidence = 0.86
# Image 7: Predicted Label = 0, Confidence = 0.76
# Image 8: Predicted Label = 0, Confidence = 1.00
# Image 9: Predicted Label = 0, Confidence = 0.97
# Image 10: Predicted Label = 0, Confidence = 0.94
# Image 11: Predicted Label = 0, Confidence = 0.99
# Image 12: Predicted Label = 3, Confidence = 0.36
# Image 13: Predicted Label = 0, Confidence = 0.99
# Image 14: Predicted Label = 0, Confidence = 0.92
# Image 15: Predicted Label = 1, Confidence = 0.49
# Image 16: Predicted Label = 0, Confidence = 0.89
# Image 17: Predicted Label = 0, Confidence = 0.99
# Image 18: Predicted Label = 0, Confidence = 0.92
# Image 19: Predicted Label = 0, Confidence = 0.95
# Image 20: Predicted Label = 0, Confidence = 0.99
# Image 21: Predicted Label = 1, Confidence = 0.88
# Image 22: Predicted Label = 0, Confidence = 0.94
# Image 23: Predicted Label = 2, Confidence = 0.67
# Image 24: Predicted Label = 0, Confidence = 0.66
# Image 25: Predicted Label = 0, Confidence = 0.98
# Image 26: Predicted Label = 3, Confidence = 0.50
# Image 27: Predicted Label = 0, Confidence = 0.67
# Image 28: Predicted Label = 2, Confidence = 0.60
# Image 29: Predicted Label = 0, Confidence = 0.90
# Image 30: Predicted Label = 0, Confidence = 0.92
# Image 31: Predicted Label = 0, Confidence = 0.93
# Image 32: Predicted Label = 0, Confidence = 1.00
# Image 33: Predicted Label = 0, Confidence = 0.99
# Image 34: Predicted Label = 0, Confidence = 0.89
# Image 35: Predicted Label = 0, Confidence = 0.98
# Image 36: Predicted Label = 3, Confidence = 0.45
# Image 37: Predicted Label = 0, Confidence = 0.70
# Image 38: Predicted Label = 0, Confidence = 0.87
# Image 39: Predicted Label = 0, Confidence = 0.81
# Image 40: Predicted Label = 0, Confidence = 0.66
# Image 41: Predicted Label = 1, Confidence = 0.72
# Image 42: Predicted Label = 1, Confidence = 0.96
# Image 43: Predicted Label = 1, Confidence = 0.91
# Image 44: Predicted Label = 1, Confidence = 0.87
# Image 45: Predicted Label = 1, Confidence = 0.88
# Image 46: Predicted Label = 1, Confidence = 0.58
# Image 47: Predicted Label = 1, Confidence = 0.86
# Image 48: Predicted Label = 1, Confidence = 0.90
# Image 49: Predicted Label = 1, Confidence = 0.98
# Image 50: Predicted Label = 1, Confidence = 0.99
# Image 51: Predicted Label = 1, Confidence = 0.73
# Image 52: Predicted Label = 1, Confidence = 0.99
# Image 53: Predicted Label = 1, Confidence = 1.00
# Image 54: Predicted Label = 1, Confidence = 0.92
# Image 55: Predicted Label = 1, Confidence = 0.61
# Image 56: Predicted Label = 1, Confidence = 0.96
# Image 57: Predicted Label = 1, Confidence = 0.80
# Image 58: Predicted Label = 0, Confidence = 0.90
# Image 59: Predicted Label = 2, Confidence = 0.79
# Image 60: Predicted Label = 2, Confidence = 0.89
# Image 61: Predicted Label = 2, Confidence = 0.88
# Image 62: Predicted Label = 2, Confidence = 0.83
# Image 63: Predicted Label = 2, Confidence = 0.74
# Image 64: Predicted Label = 0, Confidence = 0.76
# Image 65: Predicted Label = 2, Confidence = 0.87
# Image 66: Predicted Label = 2, Confidence = 0.99
# Image 67: Predicted Label = 2, Confidence = 0.88
# Image 68: Predicted Label = 3, Confidence = 0.98
# Image 69: Predicted Label = 2, Confidence = 0.83
# Image 70: Predicted Label = 2, Confidence = 0.61
# Image 71: Predicted Label = 2, Confidence = 0.77
# Image 72: Predicted Label = 2, Confidence = 0.75
# Image 73: Predicted Label = 2, Confidence = 0.61
# Image 74: Predicted Label = 0, Confidence = 0.87
# Image 75: Predicted Label = 2, Confidence = 0.48
# Image 76: Predicted Label = 2, Confidence = 0.91
# Image 77: Predicted Label = 2, Confidence = 0.83
# Image 78: Predicted Label = 2, Confidence = 0.85
# Image 79: Predicted Label = 2, Confidence = 0.70
# Image 80: Predicted Label = 0, Confidence = 0.86
# Image 81: Predicted Label = 0, Confidence = 0.67
# Image 82: Predicted Label = 3, Confidence = 0.45
# Image 83: Predicted Label = 3, Confidence = 0.87
# Image 84: Predicted Label = 3, Confidence = 0.97
# Image 85: Predicted Label = 3, Confidence = 0.52
# Image 86: Predicted Label = 1, Confidence = 0.80
# Image 87: Predicted Label = 3, Confidence = 0.82
# Image 88: Predicted Label = 3, Confidence = 0.98
# Image 89: Predicted Label = 3, Confidence = 0.98
# Image 90: Predicted Label = 3, Confidence = 0.69
# Image 91: Predicted Label = 3, Confidence = 0.80
# Image 92: Predicted Label = 3, Confidence = 0.95

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# **Validation with Wrong Labels (Performa Evaluasi)**
# Confusion Matrix untuk wrong labels
cm_wrong_labels = confusion_matrix(val_labels, predicted_labels)

# Normalisasi Confusion Matrix
cm_wrong_labels_normalized = cm_wrong_labels.astype('float') / cm_wrong_labels.sum(axis=1)[:, np.newaxis]

# Plot Heatmap untuk Wrong Labels
plt.figure(figsize=(10, 8))
sns.heatmap(cm_wrong_labels_normalized, annot=True, cmap='Reds', fmt='.2f', xticklabels=classes, yticklabels=classes)
plt.title('Confusion Matrix with Wrong Labels (Normalized)')
plt.xlabel('Predicted Labels')
plt.ylabel('Actual Labels')
plt.show()

# Classification Report untuk Wrong Labels
print("Classification Report (Wrong Labels):")
print(classification_report(val_labels, predicted_labels, target_names=classes, zero_division=0))

# **Testing Without Labels (Prediksi Saja)**
# Visualisasi hasil prediksi pada test dataset
print("\nTest Predictions (No Labels):")
plt.figure(figsize=(15, 10))
for i in range(8):  # Menampilkan 8 gambar pertama
    plt.subplot(2, 4, i + 1)
    plt.imshow(val_images[i] / 255.0)  # Normalisasi jika perlu
    plt.title(f"Pred: {classes[test_predicted_labels[i]]}\nConf: {np.max(test_predictions[i]):.2f}")
    plt.axis('off')
plt.tight_layout()
plt.show()

# **Grafik Akurasi dan Loss (Training vs Validation)**
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot Akurasi
plt.figure(figsize=(12, 6))
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Classification Report (Wrong Labels):
#                precision    recall  f1-score   support
#
#   bercak-daun       0.84      0.80      0.82        64
#    hawar-daun       0.75      0.86      0.80        21
#    karat-daun       0.74      0.80      0.77        35
# pengorok-daun       0.83      0.71      0.77        21
#
#      accuracy                           0.79       141
#     macro avg       0.79      0.79      0.79       141
#  weighted avg       0.80      0.79      0.79       141
#
#
# Test Predictions (No Labels):
